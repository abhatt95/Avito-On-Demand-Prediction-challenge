# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
from sklearn import preprocessing
from nltk.corpus import stopwords 
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import gc
from sklearn.model_selection import train_test_split
import xgboost as xgb
from scipy.sparse import hstack, csr_matrix

# %%
## reading train and test data 
traindata = pd.read_csv('train.csv', index_col = "item_id", parse_dates = ["activation_date"])
traindata_index = traindata.index
testdata = pd.read_csv('test.csv', index_col = "item_id", parse_dates = ["activation_date"])
testdata_index = testdata.index

# %%
train_output = traindata.deal_probability.copy().clip(0.0, 1.0)

# %%
total_data = pd.concat([traindata,testdata],axis=0)

# %%
del traindata,testdata
gc.collect()
# Out:
# 14

# %%
## setting dates 
total_data["Weekday"] = total_data['activation_date'].dt.weekday
total_data["Weekend_no"] = total_data['activation_date'].dt.week
total_data["day"] = total_data['activation_date'].dt.day

# %%
## encoding 1 if image present 0 if not present 
total_data['image'].fillna(0, inplace=True)
total_data['image_status'] = np.where(total_data['image']==0, 0, 1)

# %%
## dropping date and image column 
total_data.drop(["activation_date","image"],axis=1,inplace=True)

# %%
total_data.head()
# Out:
#                            category_name              city  deal_probability  \
# item_id
# b912c3c6a6ad  Товары для детей и игрушки      Екатеринбург           0.12789
# 2dac0150717d           Мебель и интерьер            Самара           0.00000
# ba83aefab5dc               Аудио и видео    Ростов-на-Дону           0.43177
# 02996f1dd2ea  Товары для детей и игрушки  Набережные Челны           0.80323
# 7c90be56d2ab                  Автомобили         Волгоград           0.20797
#
#                                                     description  image_top_1  \
# item_id
# b912c3c6a6ad  Кокон для сна малыша,пользовались меньше месяц...       1008.0
# 2dac0150717d          Стойка для одежды, под вешалки. С бутика.        692.0
# ba83aefab5dc  В хорошем состоянии, домашний кинотеатр с blu ...       3032.0
# 02996f1dd2ea                             Продам кресло от0-25кг        796.0
# 7c90be56d2ab                           Все вопросы по телефону.       2264.0
#
#               item_seq_number                      param_1     param_2  \
# item_id
# b912c3c6a6ad                2    Постельные принадлежности         NaN
# 2dac0150717d               19                       Другое         NaN
# ba83aefab5dc                9  Видео, DVD и Blu-ray плееры         NaN
# 02996f1dd2ea              286         Автомобильные кресла         NaN
# 7c90be56d2ab                3                   С пробегом  ВАЗ (LADA)
#
#              param_3 parent_category_name    price                 region  \
# item_id
# b912c3c6a6ad     NaN          Личные вещи    400.0   Свердловская область
# 2dac0150717d     NaN      Для дома и дачи   3000.0      Самарская область
# ba83aefab5dc     NaN  Бытовая электроника   4000.0     Ростовская область
# 02996f1dd2ea     NaN          Личные вещи   2200.0              Татарстан
# 7c90be56d2ab    2110            Транспорт  40000.0  Волгоградская область
#
#                               title       user_id user_type  Weekday  \
# item_id
# b912c3c6a6ad  Кокоби(кокон для сна)  e00f8ff2eaf9   Private        1
# 2dac0150717d      Стойка для Одежды  39aeb48f0017   Private        6
# ba83aefab5dc         Philips bluray  91e2f88dd6e3   Private        0
# 02996f1dd2ea             Автокресло  bf5cccea572d   Company        5
# 7c90be56d2ab         ВАЗ 2110, 2003  ef50846afc0b   Private        3
#
#               Weekend_no  day  image_status
# item_id
# b912c3c6a6ad          13   28             1
# 2dac0150717d          12   26             1
# ba83aefab5dc          12   20             1
# 02996f1dd2ea          12   25             1
# 7c90be56d2ab          11   16             1

# %%
## assigning categorical variables to most of the data columns except description and title 
categorical = ["user_id","region","city","parent_category_name","category_name","user_type",
               "image_top_1","param_1","param_2","param_3"]
from sklearn import preprocessing
xgbencoder = preprocessing.LabelEncoder()
for col in categorical:
    total_data[col] = xgbencoder.fit_transform(total_data[col].astype(str))

# %%
total_data.head()
# Out:
#               category_name  city  deal_probability  \
# item_id
# b912c3c6a6ad             42   462           0.12789
# 2dac0150717d             22  1314           0.00000
# ba83aefab5dc              2  1290           0.43177
# 02996f1dd2ea             42   950           0.80323
# 7c90be56d2ab              0   318           0.20797
#
#                                                     description  image_top_1  \
# item_id
# b912c3c6a6ad  Кокон для сна малыша,пользовались меньше месяц...           12
# 2dac0150717d          Стойка для одежды, под вешалки. С бутика.         2722
# ba83aefab5dc  В хорошем состоянии, домашний кинотеатр с blu ...         2259
# 02996f1dd2ea                             Продам кресло от0-25кг         2837
# 7c90be56d2ab                           Все вопросы по телефону.         1407
#
#               item_seq_number  param_1  param_2  param_3  \
# item_id
# b912c3c6a6ad                2      249      112     1217
# 2dac0150717d               19      122      112     1217
# ba83aefab5dc                9       84      112     1217
# 02996f1dd2ea              286       38      112     1217
# 7c90be56d2ab                3      278      124       46
#
#               parent_category_name    price  region                  title  \
# item_id
# b912c3c6a6ad                     4    400.0      19  Кокоби(кокон для сна)
# 2dac0150717d                     2   3000.0      17      Стойка для Одежды
# ba83aefab5dc                     0   4000.0      16         Philips bluray
# 02996f1dd2ea                     4   2200.0      21             Автокресло
# 7c90be56d2ab                     6  40000.0       4         ВАЗ 2110, 2003
#
#               user_id  user_type  Weekday  Weekend_no  day  image_status
# item_id
# b912c3c6a6ad   884270          1        1          13   28             1
# 2dac0150717d   227908          1        6          12   26             1
# ba83aefab5dc   576261          1        0          12   20             1
# 02996f1dd2ea   755087          0        5          12   25             1
# 7c90be56d2ab   944363          1        3          11   16             1

# %%
total_data['no_of_words_title'] = total_data['title'].apply(lambda x : len(str(x).split()))

# %%
total_data['no_of_words_description'] = total_data['description'].apply(lambda x : len(str(x).split()))

# %%
total_data.head()
# Out:
#               category_name  city  deal_probability  \
# item_id
# b912c3c6a6ad             42   462           0.12789
# 2dac0150717d             22  1314           0.00000
# ba83aefab5dc              2  1290           0.43177
# 02996f1dd2ea             42   950           0.80323
# 7c90be56d2ab              0   318           0.20797
#
#                                                     description  image_top_1  \
# item_id
# b912c3c6a6ad  Кокон для сна малыша,пользовались меньше месяц...           12
# 2dac0150717d          Стойка для одежды, под вешалки. С бутика.         2722
# ba83aefab5dc  В хорошем состоянии, домашний кинотеатр с blu ...         2259
# 02996f1dd2ea                             Продам кресло от0-25кг         2837
# 7c90be56d2ab                           Все вопросы по телефону.         1407
#
#               item_seq_number  param_1  param_2  param_3  \
# item_id
# b912c3c6a6ad                2      249      112     1217
# 2dac0150717d               19      122      112     1217
# ba83aefab5dc                9       84      112     1217
# 02996f1dd2ea              286       38      112     1217
# 7c90be56d2ab                3      278      124       46
#
#               parent_category_name        ...          region  \
# item_id                                   ...
# b912c3c6a6ad                     4        ...              19
# 2dac0150717d                     2        ...              17
# ba83aefab5dc                     0        ...              16
# 02996f1dd2ea                     4        ...              21
# 7c90be56d2ab                     6        ...               4
#
#                               title user_id  user_type  Weekday  Weekend_no  \
# item_id
# b912c3c6a6ad  Кокоби(кокон для сна)  884270          1        1          13
# 2dac0150717d      Стойка для Одежды  227908          1        6          12
# ba83aefab5dc         Philips bluray  576261          1        0          12
# 02996f1dd2ea             Автокресло  755087          0        5          12
# 7c90be56d2ab         ВАЗ 2110, 2003  944363          1        3          11
#
#               day  image_status  no_of_words_description  no_of_words_title
# item_id
# b912c3c6a6ad   28             1                        7                  3
# 2dac0150717d   26             1                        7                  3
# ba83aefab5dc   20             1                       17                  2
# 02996f1dd2ea   25             1                        3                  1
# 7c90be56d2ab   16             1                        4                  3
#
# [5 rows x 21 columns]

# %%
total_data['no_of_chars_title'] = total_data['title'].apply(lambda x : len(str(x)))

# %%
total_data['no_of_chars_description'] = total_data['description'].apply(lambda x : len(str(x)))

# %%
total_data.head(5)
# Out:
#               category_name  city  deal_probability  \
# item_id
# b912c3c6a6ad             42   462           0.12789
# 2dac0150717d             22  1314           0.00000
# ba83aefab5dc              2  1290           0.43177
# 02996f1dd2ea             42   950           0.80323
# 7c90be56d2ab              0   318           0.20797
#
#                                                     description  image_top_1  \
# item_id
# b912c3c6a6ad  Кокон для сна малыша,пользовались меньше месяц...           12
# 2dac0150717d          Стойка для одежды, под вешалки. С бутика.         2722
# ba83aefab5dc  В хорошем состоянии, домашний кинотеатр с blu ...         2259
# 02996f1dd2ea                             Продам кресло от0-25кг         2837
# 7c90be56d2ab                           Все вопросы по телефону.         1407
#
#               item_seq_number  param_1  param_2  param_3  \
# item_id
# b912c3c6a6ad                2      249      112     1217
# 2dac0150717d               19      122      112     1217
# ba83aefab5dc                9       84      112     1217
# 02996f1dd2ea              286       38      112     1217
# 7c90be56d2ab                3      278      124       46
#
#               parent_category_name           ...             user_id  \
# item_id                                      ...
# b912c3c6a6ad                     4           ...              884270
# 2dac0150717d                     2           ...              227908
# ba83aefab5dc                     0           ...              576261
# 02996f1dd2ea                     4           ...              755087
# 7c90be56d2ab                     6           ...              944363
#
#               user_type Weekday  Weekend_no  day  image_status  \
# item_id
# b912c3c6a6ad          1       1          13   28             1
# 2dac0150717d          1       6          12   26             1
# ba83aefab5dc          1       0          12   20             1
# 02996f1dd2ea          0       5          12   25             1
# 7c90be56d2ab          1       3          11   16             1
#
#               no_of_words_title  no_of_words_description  no_of_chars_title  \
# item_id
# b912c3c6a6ad                  3                        7                 38
# 2dac0150717d                  3                        7                 32
# ba83aefab5dc                  2                       17                 14
# 02996f1dd2ea                  1                        3                 20
# 7c90be56d2ab                  3                        4                 17
#
#               no_of_chars_description
# item_id
# b912c3c6a6ad                      108
# 2dac0150717d                       73
# ba83aefab5dc                      168
# 02996f1dd2ea                       38
# 7c90be56d2ab                       44
#
# [5 rows x 23 columns]

# %%
total_data.columns
# Out:
# Index([u'category_name', u'city', u'deal_probability', u'description',
#        u'image_top_1', u'item_seq_number', u'param_1', u'param_2', u'param_3',
#        u'parent_category_name', u'price', u'region', u'title', u'user_id',
#        u'user_type', u'Weekday', u'Weekend_no', u'day', u'image_status',
#        u'no_of_words_title', u'no_of_words_description', u'no_of_chars_title',
#        u'no_of_chars_description'],
#       dtype='object')

# %%
# error wont come in sequence 
notext = total_data[['category_name','city','image_top_1','item_seq_number','param_1','param_2','param_3','parent_category_name','price','region','title','user_id','user_type','Weekday','Weekend_no','day','image_status','no_of_words_description','no_of_words_title','no_of_chars_title','no_of_chars_description','deal_probability']]

# %%
notext['price'].fillna(0, inplace=True)

# %%
#columnname = notext.columns 
#for i in columnname:
#    if 
#    print notext[i].isnull().values.any()

# %%
X = notext.loc[traindata_index,:]

# %%
## saving train data which dosent have any text processing like hashing or TIFDR 
X.to_csv('./processeddata/traindata_no_text_processing.csv',header=True)

# %%
y = notext.loc[testdata_index,:]
y.head()
# Out:
#               category_name  city  image_top_1  item_seq_number  param_1  \
# item_id
# 6544e41a8817             10   318         1137               66      110
# 65b9484d670f              5   993         3063                4      119
# 8bab230b2ecd              2   151         2178               15      318
# 8e348601fefc              4  1319         3063               70      108
# 8bd2fe400b89             42   243            6               15      102
#
#               param_2  param_3  parent_category_name    price  region  \
# item_id
# 6544e41a8817      198       74                     4      0.0       4
# 65b9484d670f      112     1217                     8   3000.0      19
# 8bab230b2ecd      112     1217                     0  15000.0      12
# 8e348601fefc      131     1217                     2   4500.0      18
# 8bd2fe400b89      112     1217                     4   4900.0      14
#
#                     ...        user_type  Weekday  Weekend_no  day  \
# item_id             ...
# 6544e41a8817        ...                1        1          16   18
# 65b9484d670f        ...                1        6          15   16
# 8bab230b2ecd        ...                1        0          16   17
# 8e348601fefc        ...                1        0          16   17
# 8bd2fe400b89        ...                1        5          15   15
#
#               image_status  no_of_words_description  no_of_words_title  \
# item_id
# 6544e41a8817             1                        2                  2
# 65b9484d670f             0                       10                  2
# 8bab230b2ecd             1                       21                  1
# 8e348601fefc             0                       12                  3
# 8bd2fe400b89             1                       10                  2
#
#               no_of_chars_title  no_of_chars_description  deal_probability
# item_id
# 6544e41a8817                 29                       23               NaN
# 65b9484d670f                 31                      154               NaN
# 8bab230b2ecd                  3                      233               NaN
# 8e348601fefc                 24                      155               NaN
# 8bd2fe400b89                 32                      106               NaN
#
# [5 rows x 22 columns]

# %%
y = y.iloc[:,0:y.shape[1]-1]
y.head()
# Out:
#               category_name  city  image_top_1  item_seq_number  param_1  \
# item_id
# 6544e41a8817             10   318         1137               66      110
# 65b9484d670f              5   993         3063                4      119
# 8bab230b2ecd              2   151         2178               15      318
# 8e348601fefc              4  1319         3063               70      108
# 8bd2fe400b89             42   243            6               15      102
#
#               param_2  param_3  parent_category_name    price  region  \
# item_id
# 6544e41a8817      198       74                     4      0.0       4
# 65b9484d670f      112     1217                     8   3000.0      19
# 8bab230b2ecd      112     1217                     0  15000.0      12
# 8e348601fefc      131     1217                     2   4500.0      18
# 8bd2fe400b89      112     1217                     4   4900.0      14
#
#                        ...            user_id  user_type  Weekday  Weekend_no  \
# item_id                ...
# 6544e41a8817           ...             867817          1        1          16
# 65b9484d670f           ...             181851          1        6          15
# 8bab230b2ecd           ...              45341          1        0          16
# 8e348601fefc           ...             375979          1        0          16
# 8bd2fe400b89           ...             141497          1        5          15
#
#               day  image_status  no_of_words_description  no_of_words_title  \
# item_id
# 6544e41a8817   18             1                        2                  2
# 65b9484d670f   16             0                       10                  2
# 8bab230b2ecd   17             1                       21                  1
# 8e348601fefc   17             0                       12                  3
# 8bd2fe400b89   15             1                       10                  2
#
#               no_of_chars_title  no_of_chars_description
# item_id
# 6544e41a8817                 29                       23
# 65b9484d670f                 31                      154
# 8bab230b2ecd                  3                      233
# 8e348601fefc                 24                      155
# 8bd2fe400b89                 32                      106
#
# [5 rows x 21 columns]

# %%
y.to_csv('./processeddata/testdata_no_text_processing.csv',header=True)

# %%
del X,y,notext
gc.collect()
# Out:
# 120

# %%
## now making features using Term Frequency Inverse Document Frequency Stage 
print("Term Frequency Inverse Document Frequency Stage")
# Out:
# Term Frequency Inverse Document Frequency Stage

# %%
## for text features 
tfeatures = ["description", "title"]

for cols in tfeatures:
    total_data[cols] = total_data[cols].astype(str) 
    total_data[cols] = total_data[cols].astype(str).fillna('missing') # FILL NA

# %%
russian_stop = set(stopwords.words('russian'))

# %%
## first on title 
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words=russian_stop,
                                   use_idf=False, 
                                   norm='l1',
                                   analyzer =  'word',
                                   sublinear_tf =  True,
                                    dtype =  np.float32,
                                    smooth_idf  = False,
                                    ngram_range=(1, 2),
                                    max_features=5000,
)

# %%
# %%time
col_title = tfidf_vectorizer.fit(total_data['title'])
# Out:
# CPU times: user 50.2 s, sys: 2.19 s, total: 52.4 s
# Wall time: 51.4 s

# %%
print "Number of stopwords chosen in title is",len(col_title.stop_words)
# Out:
# Number of stopwords chosen in title is 151

# %%
# %%time 
col_title_values = tfidf_vectorizer.transform(total_data['title'])
# Out:
# CPU times: user 41.8 s, sys: 1.61 s, total: 43.5 s
# Wall time: 42.5 s

# %%
#print col_title_values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer2 = TfidfVectorizer(stop_words=russian_stop,
                                   use_idf=False, 
                                   norm='l1',
                                   analyzer =  'word',
                                   sublinear_tf =  True,
                                    dtype =  np.float32,
                                    smooth_idf  = False,
                                    ngram_range=(1, 2),
                                    max_features=5000,
)

# %%
# %%time
col_description = tfidf_vectorizer2.fit(total_data['description'])
# Out:
# CPU times: user 5min 20s, sys: 2min 6s, total: 7min 27s
# Wall time: 9min 34s

# %%
# %%time 
col_description_values = tfidf_vectorizer2.transform(total_data['description'])
# Out:
# CPU times: user 3min 1s, sys: 25.5 s, total: 3min 27s
# Wall time: 5min 36s

# %%
total_data.drop(tfeatures, axis=1,inplace=True)

# %%
# https://www.kaggle.com/gemartin/load-data-reduce-memory-usage
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else: df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
totaldata = reduce_mem_usage(total_data)
# Out:
# Memory usage of dataframe is 337.00 MB
# Memory usage after optimization is: 88.00 MB
# Decreased by 73.0%

# %%
totaldata.drop(['deal_probability'], axis = 1, inplace = True )

# %%
totaldata.head()
# Out:
#               category_name  city  image_top_1  item_seq_number  param_1  \
# item_id
# b912c3c6a6ad             42   462           12                2      249
# 2dac0150717d             22  1314         2722               19      122
# ba83aefab5dc              2  1290         2259                9       84
# 02996f1dd2ea             42   950         2837              286       38
# 7c90be56d2ab              0   318         1407                3      278
#
#               param_2  param_3  parent_category_name    price  region  \
# item_id
# b912c3c6a6ad      112     1217                     4    400.0      19
# 2dac0150717d      112     1217                     2   3000.0      17
# ba83aefab5dc      112     1217                     0   4000.0      16
# 02996f1dd2ea      112     1217                     4   2200.0      21
# 7c90be56d2ab      124       46                     6  40000.0       4
#
#               user_id  user_type  Weekday  Weekend_no  day  image_status  \
# item_id
# b912c3c6a6ad   884270          1        1          13   28             1
# 2dac0150717d   227908          1        6          12   26             1
# ba83aefab5dc   576261          1        0          12   20             1
# 02996f1dd2ea   755087          0        5          12   25             1
# 7c90be56d2ab   944363          1        3          11   16             1
#
#               no_of_words_title  no_of_words_description  no_of_chars_title  \
# item_id
# b912c3c6a6ad                  3                        7                 38
# 2dac0150717d                  3                        7                 32
# ba83aefab5dc                  2                       17                 14
# 02996f1dd2ea                  1                        3                 20
# 7c90be56d2ab                  3                        4                 17
#
#               no_of_chars_description
# item_id
# b912c3c6a6ad                      108
# 2dac0150717d                       73
# ba83aefab5dc                      168
# 02996f1dd2ea                       38
# 7c90be56d2ab                       44

# %%
# %%time 
alltrain = hstack([csr_matrix(totaldata.loc[traindata_index,:].values),col_title_values[0:traindata_index.shape[0]],col_description_values[0:traindata_index.shape[0]]]) # Sparse Matrix
# Out:
# CPU times: user 4.74 s, sys: 6.42 s, total: 11.2 s
# Wall time: 33.7 s

# %%
# %%time
alltest = hstack([csr_matrix(totaldata.loc[testdata_index,:].values),col_title_values[0:testdata_index.shape[0]],col_description_values[0:testdata_index.shape[0]]]) # Sparse Matrix
# Out:
# CPU times: user 1.69 s, sys: 978 ms, total: 2.67 s
# Wall time: 3.7 s

# %%
# %%time
import pickle
file = open('./processeddata/perfect_train_5000.pkl','wb')
pickle.dump(alltrain,file )
file.close()
# to read them back 
# alltrain = pickle.load( open( "perfecttrain.pkl", "rb" ) )
# Out:
# CPU times: user 1min 14s, sys: 17 s, total: 1min 31s
# Wall time: 4min 8s

# %%
# %%time
import pickle
file = open('./processeddata/perfect_test_5000.pkl','wb')
pickle.dump(alltest, file)
file.close()
# Out:
# CPU times: user 24.9 s, sys: 2.88 s, total: 27.8 s
# Wall time: 1min 9s

# %%
# %%time
file = open('./processeddata/perfect_train_output_5000.pkl','wb')
pickle.dump(train_output,file )
file.close()
# Out:
# CPU times: user 20.3 s, sys: 2.86 s, total: 23.2 s
# Wall time: 1min 44s

# %%
X_train, X_valid, y_train, y_valid = train_test_split(alltrain, train_output, test_size=0.10, random_state=5)

# %%
# %%time
import xgboost as xgb
xgdmat=xgb.DMatrix(X_train,y_train)
our_params={'eta':0.1,'seed':0,'subsample':0.8,'colsample_bytree':0.8,'objective':'reg:linear','max_depth':5,'min_child_weight':1}
final_gb=xgb.train(our_params,xgdmat)
# Out:
# CPU times: user 1min 48s, sys: 3.7 s, total: 1min 52s
# Wall time: 3min 9s

# %%
# %%time
tesdmat=xgb.DMatrix(X_train)
y_pred=final_gb.predict(tesdmat)
print(y_pred)
# Out:
# [ 0.29787976  0.22403917  0.2686896  ...,  0.25952417  0.21479341
#   0.22403917]
# CPU times: user 1.93 s, sys: 1.61 s, total: 3.54 s
# Wall time: 4.65 s

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_train,y_pred)
# Out:
# 0.24489483427173372
